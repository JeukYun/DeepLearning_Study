# %%
import pandas as pd

# 데이터 : 유튜브 데일리 인기 동영상
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %% [markdown]
# # 1.유튜브 데일리 인기영상

# %% [markdown]
# 1. 인기동영상 제작횟수가 많은 채널 상위 10개명을 출력하라 (날짜기준, 중복포함)

# %%
df[df['channelTitle'].isin(df['channelTitle'].value_counts().head(10).index)]['channelTitle'].unique()
# Out:
# array(['장삐쭈', '총몇명', '파뿌리', '짤툰', '런닝맨 - 스브스 공식 채널',
#        '엠뚜루마뚜루 : MBC 공식 종합 채널', 'SPOTV', '채널 십오야', '이과장', 'BANGTANTV'],
#       dtype=object)

# %% [markdown]
# 2. 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df[df['dislikes'] > df['likes']]['channelTitle'].unique()
# Out:
# array(['핫도그TV', 'ASMR 애정TV', '하얀트리HayanTree', '양팡 YangPang',
#        '철구형 (CHULTUBE)', '왜냐맨하우스', '(MUTUBE)와꾸대장봉준', '오메킴TV', '육지담',
#        'MapleStory_KR', 'ROAD FIGHTING CHAMPIONSHIP', '사나이 김기훈',
#        '나혼자산다 STUDIO', 'Gen.G esports'], dtype=object)

# %% [markdown]
# 3. 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라

# %%
ID = df['channelId'].unique()
a = []

for i in ID:
    if len(df[df['channelId'] == i]['channelTitle'].unique()) > 1:
        a.append(i)
print(len(a))
# Out:
# 71

# %% [markdown]
# 4. 일요일에 인기있었던 영상들중 가장많은 영상 종류(categoryId)는 무엇인가?

# %%
df2 = df
df2['trending_date2'] = pd.to_datetime(df2['trending_date2'])

# %%
df_sun = df2[df2['trending_date2'].dt.day_of_week == 6]
df_sun['categoryId'].value_counts().head(1).index[0]
# Out:
# 24

# %% [markdown]
# 5. 각 요일별 인기 영상들의 categoryId는 각각 몇개 씩인지 하나의 데이터 프레임으로 표현하라

# %%
df2['date'] = df2['trending_date2'].dt.day_name()
df3 = df2[['date', 'categoryId']].groupby(['date', 'categoryId'], as_index = False).size()
df3.pivot_table(index = 'categoryId', columns = 'date')
# Out:
#              size
# date       Friday Monday Saturday Sunday Thursday Tuesday Wednesday
# categoryId
# 1             243    263      255    274      246     257       234
# 2             120    105      119     99      128     119       129
# 10            833    837      776    830      890     894       917
# 15            187    215      198    217      207     208       207
# 17            633    668      592    636      682     708       706
# 19             90     92       87     91       92      89        85
# 20            283    298      296    289      282     285       291
# 22           1288   1373     1289   1337     1341    1375      1333
# 23            568    594      570    556      560     569       566
# 24           2976   3148     3066   3096     2954    3084      3090
# 25            444    453      422    437      470     452       468
# 26            369    378      364    363      375     394       385
# ...

# %% [markdown]
# 6. 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다. viewcount대비 댓글수가 가장 높은 영상을 확인하라 (view_count값이 0인 경우는 제외한다)

# %%
df3 = df[(df['view_count'] != 0) & df['comment_count'] != 0]
df3['high'] = df3['view_count']/df3['comment_count']
print(df3.sort_values(by = 'high').head(1)['title'])
# Out:
# 51047    60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)
# Name: title, dtype: object
# C:\Users\yju12\AppData\Local\Temp\ipykernel_8660\506425614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['high'] = df3['view_count']/df3['comment_count']

# %% [markdown]
# 7. 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다.viewcount대비 댓글수가 가장 낮은 영상을 확인하라 (view_counts, ratio값이 0인경우는 제외한다.)

# %%
df3.sort_values(by = 'high', ascending = False).head(1)['title']
# Out:
# 46005    Join the BTS #PermissiontoDance Challenge only...
# Name: title, dtype: object

# %% [markdown]
# 8. like 대비 dislike의 수가 가장 적은 영상은 무엇인가? (like, dislike 값이 0인경우는 제외한다)

# %%
df3 = df[~(df['likes'] == 0) & ~(df['dislikes'] == 0)]
df3['ratio'] = df['likes']/df['dislikes']
df3.sort_values(by = 'ratio', ascending = False).head(1)['title']
# Out:
# C:\Users\yju12\AppData\Local\Temp\ipykernel_8660\2762365132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['ratio'] = df['likes']/df['dislikes']
# 11477    [줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가...
# Name: title, dtype: object

# %% [markdown]
# 9. 가장많은 트렌드 영상을 제작한 채널의 이름은 무엇인가? (날짜기준, 중복포함)

# %%
df['channelTitle'].value_counts()
# Out:
# 짤툰                       372
# 파뿌리                      318
# SPOTV                    318
# 런닝맨 - 스브스 공식 채널          313
# 엠뚜루마뚜루 : MBC 공식 종합 채널    293
#                         ...
# NamSeok Byun               1
# 공원생활 / ParkLife            1
# Brave Girls                1
# 깽냥툰 KY'T                   1
# 알파                         1
# Name: channelTitle, Length: 1832, dtype: int64

# %% [markdown]
# 10. ???? 20회(20일)이상 인기동영상 리스트에 포함된 동영상의 숫자는?

# %%
sum(df[['title', 'channelId']].value_counts() >= 20)
# 왜 channelId가 있는거랑 없는거의 개수차이가 남??
# Out:
# 40
